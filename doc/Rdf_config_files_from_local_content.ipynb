# %%
# !pip install shexer
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.1/178.1 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 15.1 MB/s eta 0:00:00
# ...
#   Created wheel for wlighter: filename=wlighter-1.0.1-py3-none-any.whl size=5841 sha256=1014df9aa9407141b4254711be467e45e47271357ff66f4eb3cf41f434421cad
#   Stored in directory: /root/.cache/pip/wheels/a7/99/fc/827abe031e1eb32a25e3bda1affff5a8adccfecf52d5548425
# Successfully built wlighter
# ...

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE, MIXED_INSTANCES, ALL_EXAMPLES

######################  DATA ###################
raw_content = """
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix ex: <http://example.org/> .
@prefix foaf: <http://xmlns.com/foaf/0.1/> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

ex:Jimmy a foaf:Person ;  # Complete
	foaf:age "23"^^xsd:integer ;
	a ex:PersonOtherNamespace ;
	foaf:name "Jimmy" ;
	foaf:name "Jim" ;
	foaf:familyName "Jones" .

ex:Sarah a foaf:Person ;  # Complete implicit type for age
	foaf:age 22 ;
	foaf:name "Sarah" ;
	foaf:familyName "Salem" .

ex:Bella a foaf:Person ;  # Missing familyName
	foaf:age "56"^^xsd:integer ;
	foaf:name "Isabella" .

ex:David a foaf:Person ;  # Missing age and use knows
	foaf:name "David" ;
	foaf:familyName "Doulofeau" ;
	foaf:knows ex:Sarah .

ex:HumanLike foaf:name "Person" ;  # foaf properties, but not explicit type.
	foaf:familyName "Maybe" ;
	foaf:age 99 ;
	foaf:knows ex:David .

ex:x1 rdf:type foaf:Document ;
	foaf:depiction "A thing that is nice" ;
	foaf:title "A nice thing" .


ex:x2 rdf:type foaf:Document ;
	foaf:title "Another thing" .


    """
namespaces_dict = {"http://purl.org/dc/terms/": "dc",
                    "http://rdfs.org/ns/void#": "void",
                    "http://www.w3.org/2001/XMLSchema#": "xsd",
                    "http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
                    "http://purl.org/pav/": "pav",
                    "http://www.w3.org/ns/dcat#": "dcat",
                    "http://xmlns.com/foaf/0.1/": "foaf",
                    "http://www.w3.org/2002/07/owl#": "owl",
                    "http://www.w3.org/2000/01/rdf-schema#": "rdfs",
                    "http://www.w3.org/2004/02/skos/core#": "skos",
                    }

def run(target_dir,
        raw_graph,
        namespaces):


    shaper = Shaper(raw_graph=raw_graph,
                    all_classes_mode=True,
                    input_format=TURTLE,
                    namespaces_dict=namespaces,
                    disable_exact_cardinality=False,
                    detect_minimal_iri=True,
                    examples_mode=ALL_EXAMPLES,
                    instances_report_mode=MIXED_INSTANCES)


    result = shaper.shex_graph(rdfconfig_directory=target_dir, # Set this property to some value to generate rdf-config files
                               verbose=True,
                               acceptance_threshold=0,
                               string_output=True)


    print(result)  # You can print anyhow the result as an str, combined with the schemas extracted.

if __name__ == "__main__":
    ############### EXECUTION ###############

    run(target_dir="right_here",
        raw_graph=raw_content,
        namespaces=namespaces_dict)
# Out:
# 23/04/2025 10:58:19 -- Starting instance tracker...
# 23/04/2025 10:58:20 -- Instance tracker finished. 6 instances located
# 23/04/2025 10:58:20 -- Starting class profiler...
# 23/04/2025 10:58:20 -- Instance counts completed. Annotating instance features...
# 23/04/2025 10:58:20 -- Instance features annotated. Number of relevant triples computed: 22. Building shape profiles...
# 23/04/2025 10:58:20 -- Draft shape profiles built. Cleaning shape profiles...
# 23/04/2025 10:58:20 -- Shape profiles done. Working with 3 shapes.
# 23/04/2025 10:58:20 -- Detecting example features for each shape...
# 23/04/2025 10:58:20 -- Mimimal IRIs detected...
# 23/04/2025 10:58:20 -- Starting shape extraction...
# 23/04/2025 10:58:20 -- Shape drafts built. Sorting constraints...
# 23/04/2025 10:58:20 -- Constraints sorted. Adjusting cardinalities...
# 23/04/2025 10:58:20 -- Cardinalities adjusted. Cleaning empty shapes if needed...
# ...
