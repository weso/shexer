# %%
# !pip install shexer
# Out:
# Collecting shexer
#   Downloading shexer-2.5.10-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: Flask in /usr/local/lib/python3.11/dist-packages (from shexer) (3.1.0)
# Collecting Flask-Cors (from shexer)
#   Downloading flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting rdflib (from shexer)
#   Downloading rdflib-7.1.4-py3-none-any.whl.metadata (11 kB)
# Collecting SPARQLWrapper (from shexer)
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting wlighter (from shexer)
#   Downloading wlighter-1.0.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting plantuml (from shexer)
#   Downloading plantuml-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting python-xz (from shexer)
#   Downloading python_xz-0.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask->shexer) (1.9.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.11/dist-packages (from plantuml->shexer) (0.22.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib->shexer) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wlighter->shexer) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->Flask->shexer) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wlighter->shexer) (2025.1.31)
# Downloading shexer-2.5.10-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 6.4 MB/s eta 0:00:00
# Downloading flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Downloading plantuml-0.3.0-py3-none-any.whl (5.8 kB)
# Downloading python_xz-0.5.0-py3-none-any.whl (20 kB)
# Downloading rdflib-7.1.4-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 18.4 MB/s eta 0:00:00
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Building wheels for collected packages: wlighter
#   Building wheel for wlighter (setup.py) ... done
#   Created wheel for wlighter: filename=wlighter-1.0.1-py3-none-any.whl size=5841 sha256=e3e8a27ac820249c5846f020c91f19009a4d889f9bbb73cc5f190b3cb2ac1c2d
#   Stored in directory: /root/.cache/pip/wheels/a7/99/fc/827abe031e1eb32a25e3bda1affff5a8adccfecf52d5548425
# Successfully built wlighter
# Installing collected packages: rdflib, python-xz, wlighter, SPARQLWrapper, plantuml, Flask-Cors, shexer
# Successfully installed Flask-Cors-5.0.1 SPARQLWrapper-2.0.0 plantuml-0.3.0 python-xz-0.5.0 rdflib-7.1.4 shexer-2.5.10 wlighter-1.0.1

# %%
from shexer.shaper import Shaper
from shexer.consts import TURTLE
from shexer.model.federated_source import FederatedSource

_S = 0
_O = 2

namespaces_dict = {
   "http://www.w3.org/1999/02/22-rdf-syntax-ns#": "rdf",
   "http://example.org/": "ex",
   "http://weso.es/shapes/": "shape",
   "http://www.w3.org/2001/XMLSchema#": "xsd",
   "http://www.w3.org/2002/07/owl#": "owl",
   "https://biodatafuse.org/example/" : "graph",
   "http://purl.obolibrary.org/obo/": "obo",
}
toy_data_example = """
@prefix ex: <http://example.org/> .
@prefix schema: <http://schema.org/> .
@prefix wd: <http://www.wikidata.org/entity/> .
@prefix dbr: <http://dbpedia.org/resource/> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .

ex:Tokyo a ex:City ;
         rdfs:label "Tokyo" ;
	     schema:sameAs wd:Q1490 ;
		 ex:country ex:Japan .

dbr:Tokyo schema:sameAs ex:Tokyo .

ex:Oviedo a ex:City ;
          rdfs:label "Oviedo" ;
	      schema:sameAs wd:Q14317 ;
          ex:country ex:Spain .

dbr:Oviedo schema:sameAs ex:Oviedo .

ex:Japan a ex:Country ;
         rdfs:label "Japan";
         schema:sameAs wd:Q17 .

dbr:Japan schema:sameAs ex:Japan .

ex:Spain a ex:Country ;
         rdfs:label "Spain";
         schema:sameAs wd:Q29 .

dbr:Spain schema:sameAs ex:Spain .
"""


def wikidata(origin_position_in_triple=_S, link_in_federated_source=False):
    # A Federated shape is representad by one of these objects: FederatedSource
    # They can be found at shexer.model.federated_source.FederatedSource
    #
    # Parameters:
    #
    # endpoint_url: SPARQL endpoint to query the federated source
    #
    # property_link: property used to express synonymity between two URIS
    #
    # link_in_federated_source: bool. It indicates if the triple to express
    #     synonymity is expected to be found in the SPARQL endpoint of the
    #     federated source (True) or in sheXer's original input. In this case,
    #     the data of the input contains triples such as (A schema:sameAs B), so
    #     link_in_federated_source should be False. If those triples were
    #     expected to be found at Wikidata's endpoint, then it should be True.
    #
    # alias: a "label" to use for referring this source. This alias will be
    #     used in comments and to generate URIs for the federated shapes
    #     extracted.
    #
    # origin_position_in_triple: it is an integer representing a position in
    #     a triple. 0 --> subject. 1 --> predicate. 2 --> object. Valid values
    #     for this parameter are only 0 (subject) and 2 (object). This number
    #     indicates the position expected for the node that we are trying to
    #     locate synonyms for in the synonimity triple. In this case, the input
    #     content contains triples such as (ex:Tokyo schema:sameAs wd:wd:Q1490).
    #     The node that we want to locate synonyms for, ex:Tokyo, is the subject
    #     and so are all nodes connecting with Wikidata items. Then, the param
    #     origin_position_in_triple should be set to 0 (subject).
    #     In other methdod to create a FederatedSource representing DBpedia,
    #     the triples are like (dbr:Tokyo schema:sameAs ex:Tokyo). So, in that
    #     case, origin_position_in_triple should be set to 2 (object).


    return FederatedSource(endpoint_url="https://query.wikidata.org/sparql",
                           property_link="http://schema.org/sameAs",
                           link_in_federated_source=link_in_federated_source,
                           alias="Wikidata",
                           origin_position_in_triple=origin_position_in_triple)

def dbpedia(origin_position_in_triple=_O, link_in_federated_source=False):
    return FederatedSource(endpoint_url="https://dbpedia.org/sparql",
                           property_link="http://schema.org/sameAs",
                           link_in_federated_source=link_in_federated_source,
                           alias="DBpedia",
                           origin_position_in_triple=origin_position_in_triple)

def run_single_direct(raw_graph):
    shaper = Shaper(
       all_classes_mode=True,
       raw_graph=raw_graph,
       input_format=TURTLE,
       namespaces_dict=namespaces_dict,
       disable_or_statements=False,
       disable_comments=False,
       federated_sources=[wikidata()]  # federated_sources is the parameter that allows for extracted federated shapes
    )


    graph_shex = shaper.shex_graph(string_output=True)
    print(graph_shex)

def run_single_inverse(raw_graph):
    shaper = Shaper(
       all_classes_mode=True,
       raw_graph=raw_graph,
       input_format=TURTLE,
       namespaces_dict=namespaces_dict,
       disable_or_statements=False,
       disable_comments=False,
       wikidata_annotation=True,
       federated_sources=[dbpedia()]
    )

    graph_shex = shaper.shex_graph(string_output=True)
    print(graph_shex)

def run_double_fed(raw_graph):
    shaper = Shaper(
       all_classes_mode=True,
       raw_graph=raw_graph,
       input_format=TURTLE,
       namespaces_dict=namespaces_dict,
       disable_or_statements=False,
       disable_comments=False,
       wikidata_annotation=True,
       federated_sources=[wikidata(), dbpedia()]
    )


    graph_shex = shaper.shex_graph(string_output=True)
    print(graph_shex)

if __name__ == "__main__":
    run_single_direct(toy_data_example)
    print("\n\n\n\n----------------------\n\n\n\n")
    run_single_inverse(toy_data_example)
    print("\n\n\n\n----------------------\n\n\n\n")
    run_double_fed(toy_data_example)
    print("\n\n\n\n----------------------\n\n\n\n")
    print("Done!")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#    <http://www.wikidata.org/prop/P37>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P10326>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P17>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P832>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {9}
#             # 25.0 % obj: IRI. Cardinality: {15}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6344>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5843>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5198>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1151>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1740>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P12800>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {8}
#             # 25.0 % obj: IRI. Cardinality: {6}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P213>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P47>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {11}
#             # 25.0 % obj: IRI. Cardinality: {7}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1082>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {60}
#             # 25.0 % obj: IRI. Cardinality: {36}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P793>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {11}
#             # 25.0 % obj: IRI. Cardinality: {18}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6839>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9346>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5573>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P10234>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1424>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2979>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1245>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P7502>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2959>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P571>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {5}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2573>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {17}
#             # 25.0 % obj: IRI. Cardinality: {15}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P12800>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {8}
#             # 25.0 % obj: xsd:string. Cardinality: {6}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2131>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2250>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {24}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2581>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6778>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8814>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1424>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2852>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P122>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5247>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P793>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {11}
#             # 25.0 % obj: IRI. Cardinality: {18}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2981>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3422>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8763>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P150>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {21}
#             # 25.0 % obj: IRI. Cardinality: {47}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P487>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1344>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {7}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6262>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {6}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6213>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3896>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P7127>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P38>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2163>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2852>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3106>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6200>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1448>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {4}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P4841>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8885>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5008>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P901>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P150>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {20}
#             # 25.0 % obj: IRI. Cardinality: {47}
#             # 25.0 % obj: @:City_fed_Wikidata. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1332>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P38>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1589>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2936>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {15}
#             # 25.0 % obj: IRI. Cardinality: {14}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5905>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9084>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10091>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1813>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {13}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    schema1:dateModified  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3984>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2633>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1335>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1539>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10730>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P163>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5437>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {7}
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2959>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8328>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5250>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P11547>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1465>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P78>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P4427>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2855>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2853>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1792>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1343>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {11}
#             # 25.0 % obj: IRI. Cardinality: {17}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8895>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2082>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P7870>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6343>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P10291>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P7870>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P35>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P349>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9957>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P12061>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P11897>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1813>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {13}
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8885>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2579>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8406>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1036>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2924>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P10227>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2670>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P902>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6706>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P421>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P213>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8483>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3067>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8895>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P906>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P8168>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P11496>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10234>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8309>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1296>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P373>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P242>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3422>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6706>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10916>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3553>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P950>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P361>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1438>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P4802>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8370>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1417>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P242>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P11593>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {8}
#             # 25.0 % obj: IRI. Cardinality: {9}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P5739>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P5063>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6849>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P122>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P94>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8519>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3065>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P30>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6200>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9084>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P47>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # 25.0 % obj: IRI. Cardinality: {6}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P85>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5739>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2002>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3509>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P4527>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P7867>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3222>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P13390>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P30>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P271>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P206>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1740>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P13113>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2924>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2572>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P214>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P13160>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P13300>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3106>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P706>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1335>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P3911>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9475>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2046>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2633>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P982>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P214>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9100>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9241>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8248>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P12443>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P950>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P402>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P237>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8935>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9318>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P11897>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3024>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3749>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2046>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6058>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2981>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P13291>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P1617>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P11012>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P35>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P6213>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P984>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P4801>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9272>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5125>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P31>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P7502>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1705>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6573>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1889>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1559>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P4527>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P7295>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P13300>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P12515>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P12385>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9272>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1566>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1889>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P10832>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P373>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P269>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9948>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P7422>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5739>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10757>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9495>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3000>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {5}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8370>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P832>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {9}
#             # 25.0 % obj: IRI. Cardinality: {15}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2572>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P421>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P13390>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P443>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {3}
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P395>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P41>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {10}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P487>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6213>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1464>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P6385>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P2163>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P6344>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: {4}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P244>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P474>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P209>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3847>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P474>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8402>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2982>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P194>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P625>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1248>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P9466>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3001>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3509>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P1451>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: +
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P5034>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P3271>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct-normalized/P1566>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2184>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2966>  xsd:string  *;
#             # 50.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P3270>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8217>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P2670>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {4}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P10832>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P935>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P9957>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P298>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P8483>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P5587>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P299>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P1791>  IRI  ?;
#             # 50.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/P8328>  IRI  *;
#             # 50.0 % obj: IRI. Cardinality: +
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in Wikidata
#    <http://www.wikidata.org/prop/direct/P7012>  xsd:string  ?;
#             # 50.0 % obj: xsd:string. Cardinality: {1}
# ...
#             # Constraint only observed in DBpedia
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatAfricanCountries>]  ?;
#             # 25.0 % obj: <http://dbpedia.org/class/yago/WikicatAfricanCountries>. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatRomanceCountriesAndTerritories>]  ?;
#             # 25.0 % obj: <http://dbpedia.org/class/yago/WikicatRomanceCountriesAndTerritories>. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatMemberStatesOfTheEuropeanUnion>]  ?;
#             # 25.0 % obj: <http://dbpedia.org/class/yago/WikicatMemberStatesOfTheEuropeanUnion>. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatMemberStatesOfTheUnionForTheMediterranean>]  ?;
#             # 25.0 % obj: <http://dbpedia.org/class/yago/WikicatMemberStatesOfTheUnionForTheMediterranean>. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    rdf:type  [<http://dbpedia.org/class/yago/WikicatSpanish-speakingCountriesAndTerritories>]  ?;
#             # 25.0 % obj: <http://dbpedia.org/class/yago/WikicatSpanish-speakingCountriesAndTerritories>. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/anthem>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/caption>  IRI  *;
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/languagesType>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/languagesType>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/largestCity>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/largestCity>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/languages>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/languages>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/direction>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/romaji>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/altMap>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/imageMap>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/demonym>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/giniRank>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/populationCensusYear>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/altCoat>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/altFlag>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/nationalAnthem>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {3}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/cctld>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/cctld>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/timeZone>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/timeZone>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/mapCaption>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/otherSymbolType>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/populationCensus>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/currency>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/currency>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/symbolType>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/otherSymbol>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/city>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {20}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/pop>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {20}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/nationalMotto>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/div>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {12}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/religion>  IRI  *;
#             # 25.0 % obj: IRI. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/areaSqMi>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/nativeName>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/country>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/religion>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {5}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/divLink>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/motto>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/statRef>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/voy>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/religionYear>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/dateFormat>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/img>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {4}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/width>  xsd:string  *;
#             # 25.0 % obj: xsd:string. Cardinality: {2}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/currencyCode>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/largestCity>  IRI  ?;
#             # 25.0 % obj: IRI. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/populationDensitySqMi>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/iso31661Code>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/iso3166code>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/b>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/divName>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/name>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/dstNote>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/utcOffsetDst>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/ontology/currencyCode>  xsd:string  ?;
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
#    <http://dbpedia.org/property/timeZoneDst>  xsd:string  ?
#             # 25.0 % obj: xsd:string. Cardinality: {1}
#             # Constraint only observed in DBpedia
# }
#
#
#
#
#
#
#
# ----------------------
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/local/lib/python3.11/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# /usr/local/lib/python3.11/dist-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     385             s = str(s, self.encoding)
# --> 386         obj, end = self.raw_decode(s)
#     387         end = _w(s, end).end()
#
# /usr/local/lib/python3.11/dist-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     415                 idx += 3
# --> 416         return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-3-0f758392be55> in <cell line: 0>()
#     149     run_single_inverse(toy_data_example)
#     150     print("\n\n\n\n----------------------\n\n\n\n")
# --> 151     run_double_fed(toy_data_example)
#     152     print("\n\n\n\n----------------------\n\n\n\n")
#     153     print("Done!")
#
# <ipython-input-3-0f758392be55> in run_double_fed(raw_graph)
#     141
#     142
# --> 143     graph_shex = shaper.shex_graph(string_output=True)
#     144     print(graph_shex)
#     145
#
# /usr/local/lib/python3.11/dist-packages/shexer/shaper.py in shex_graph(self, string_output, output_file, output_format, acceptance_threshold, verbose, to_uml_path)
#     287                                                        output_format=output_format)
#     288
# --> 289             return serializer.serialize_shapes()  # If string return is active, returns string.
#     290
#     291
#
# /usr/local/lib/python3.11/dist-packages/shexer/io/shex/formater/shex_serializer.py in serialize_shapes(self)
#      50         self._flush()
#      51         if self._wikidata_annotation:
# ---> 52             self._annotate_wikidata_ids_in_result()
#      53         if self._string_return:
#      54             return self._string_result
#
# /usr/local/lib/python3.11/dist-packages/shexer/io/shex/formater/shex_serializer.py in _annotate_wikidata_ids_in_result(self)
#      66
#      67     def _annotate_wikidata_ids_in_result(self):
# ---> 68         self._string_result = wikidata_annotation(raw_input=self._get_raw_input_for_wikidata_annotation(),
#      69                                                   string_return=self._string_return,
#      70                                                   out_file=self._target_file,
#
# /usr/local/lib/python3.11/dist-packages/shexer/io/wikidata.py in wikidata_annotation(raw_input, string_return, out_file, format, rdfs_comments)
#       8                     generate_rdfs_comments=rdfs_comments,
#       9                     mode_column_aligned=True)
# ---> 10     result = wlig.annotate_all(out_file=out_file, string_return=string_return)
#      11     if string_return:
#      12         return result
#
# /usr/local/lib/python3.11/dist-packages/wlighter/w_lighter.py in annotate_all(self, out_file, string_return)
#     337         :return:
#     338         """
# --> 339         return self._base_annotate(out_file=out_file,
#     340                                    string_return=string_return,
#     341                                    look_for_mentions_func=self._look_for_all_mentions)
#
# /usr/local/lib/python3.11/dist-packages/wlighter/w_lighter.py in _base_annotate(self, out_file, string_return, look_for_mentions_func)
#     353
#     354         self._set_formatter(out_file, string_return, max_lenght + 2)
# --> 355         self._solve_mentions()
#     356         return self._formatter.produce_result()
#     357
#
# /usr/local/lib/python3.11/dist-packages/wlighter/w_lighter.py in _solve_mentions(self)
#     391                 curr_group = []
#     392         if len(curr_group) > 0:
# --> 393             self._entities_api_call(curr_group)
#     394
#     395     def _save_mentions(self, line_number, mentions):
#
# /usr/local/lib/python3.11/dist-packages/wlighter/w_lighter.py in _entities_api_call(self, entity_goup)
#     417         response = requests.get(_ENTITIES_API_CALL.format("|".join(entity_goup),
#     418                                                           self._languages_for_api))
# --> 419         response = response.json()
#     420         for an_entity in entity_goup:
#     421             self._ids_dict[an_entity] = \
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     976             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     979
#     980     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
